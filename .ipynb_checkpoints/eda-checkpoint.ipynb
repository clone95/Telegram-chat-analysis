# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import json 
import os
import sys  
from ipywidgets import interact, interactive, fixed, interact_manual
from IPython.display import display
import ipywidgets as widgets

matplotlib.rcParams['figure.figsize'] = (15.0, 7.0)
matplotlib.rcParams['font.size']=20
dataset_names = os.listdir('data')

data_sel = widgets.Dropdown(
    options=[x.split('.')[0] for x in dataset_names],
    description='Dataset:',
    disabled=False,
)
resample_slider = widgets.SelectionSlider(
    options=['m', 'w', 'd'],
    description='Resample:',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True
)

display(data_sel)
# Out:
# Dropdown(description='Dataset:', options=('chiara',), value='chiara')

# %%
data = pd.read_csv('data.csv')
data['date'] = data.date.apply(lambda x: pd.to_datetime(x))
data['month'] = data.date.apply(lambda x: x.month)
data['day'] = data.date.apply(lambda x: x.day)
data['hour'] = data.date.apply(lambda x: x.hour)
data['minute'] = data.date.apply(lambda x: x.minute)
data['second'] = data.date.apply(lambda x: x.second)
data = data.set_index('date')
data = data.drop(['Unnamed: 0'], axis=1)
data.head()
# Out:
#                                    da             text  month  day  hour  \
# date
# 2020-04-09 00:40:59  Giacomo Ciarlini           Si bel      4    9     0
# 2020-04-09 00:41:01  Giacomo Ciarlini        Benvenuta      4    9     0
# 2020-04-09 00:41:05  Giacomo Ciarlini  Nel mondo reale      4    9     0
# 2020-04-09 00:41:09            Chiara                😹      4    9     0
# 2020-04-09 00:41:11  Giacomo Ciarlini         Comunque      4    9     0
#
#                      minute  second
# date
# 2020-04-09 00:40:59      40      59
# 2020-04-09 00:41:01      41       1
# 2020-04-09 00:41:05      41       5
# 2020-04-09 00:41:09      41       9
# 2020-04-09 00:41:11      41      11

# %%
grouped_by_from = data.groupby('da').count()
ax = sns.barplot(x=grouped_by_from.index, y="text", data=grouped_by_from).set_title('Quanti messaggi in totale sono stati inviati?', fontsize=20);

# %%
monthly = data[['text', 'month']].groupby('month').count()
monthly.index = ['Aprile', 'Maggio', 'Giugno', 'Luglio']
monthly.plot(linewidth=4, title='Numero di messaggi inviati rispetto al mese');

# %% [markdown]
# ### Choose _resample rate_

# %%
display(resample_slider)
# Out:
# SelectionSlider(description='Resample:', options=('m', 'w', 'd'), value='m')

# %%
data[['text']].resample(resample_slider.value).count().plot(linewidth=4, title='Numero di messaggi inviati rispetto per ora del giorno');

# %%
# Out:
# IntSlider(value=0)

# %%
w.value
w.value = 100

# %%
widgets.Text(value=interact(f, x='Hi there!'), disabled=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-5750dfa4829f> in <module>
# ----> 1 widgets.Text(value=interact(f, x='Hi there!'), disabled=True)
#
# NameError: name 'f' is not defined

# %%
interact(f, x=['apples','oranges']);
# Out:
# interactive(children=(Dropdown(description='x', options=('apples', 'oranges'), value='apples'), Output()), _do…
